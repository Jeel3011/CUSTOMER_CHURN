# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/customer_churn.csv')
print(df.head())
# Out:
#    customer_id  tenure_months  monthly_usage subscription_plan  \
# 0            1             39     105.144058        Enterprise
# 1            2             52      93.390874               Pro
# 2            3             29      94.978089               Pro
# 3            4             15      57.897836               Pro
# 4            5             43      96.053267               Pro
#
#    monthly_revenue  support_tickets  last_login_days  payment_delay  churn
# 0               20                0               30              0      0
# 1               50                1               18              2      0
# 2               20                1               32              1      1
# 3               50                1               25              1      0
# 4               20                3               44              1      0

# %%
df.isnull().sum()
# Out:
# customer_id          0
# tenure_months        0
# monthly_usage        0
# subscription_plan    0
# monthly_revenue      0
# support_tickets      0
# last_login_days      0
# payment_delay        0
# churn                0
# dtype: int64

# %% [markdown]
# No Missing values.

# %%
df.dtypes
# Out:
# customer_id            int64
# tenure_months          int64
# monthly_usage        float64
# subscription_plan     object
# monthly_revenue        int64
# support_tickets        int64
# last_login_days        int64
# payment_delay          int64
# churn                  int64
# dtype: object

# %%
df.columns
# Out:
# Index(['customer_id', 'tenure_months', 'monthly_usage', 'subscription_plan',
#        'monthly_revenue', 'support_tickets', 'last_login_days',
#        'payment_delay', 'churn'],
#       dtype='object')

# %%
print(df.columns)
print(type(df))
# Out:
# Index(['customer_id', 'tenure_months', 'monthly_usage', 'subscription_plan',
#        'monthly_revenue', 'support_tickets', 'last_login_days',
#        'payment_delay', 'churn'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>

# %%
x=df.drop(columns=['churn'], axis=1)
y=df['churn']

# %% [markdown]
# we have to encode subcription plan using one hot encoding and others using standerscaler.

# %%
from sklearn.compose import ColumnTransformer
numeric_features = x.select_dtypes(include=['int64', 'float64']).columns
categorical_features = x.select_dtypes(include=['object']).columns  
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ])
X_processed = preprocessor.fit_transform(x)
print(X_processed)
# Out:
# [[-1.73170443  0.52483754  0.06374172 ...  0.          1.
#    0.        ]
#  [-1.73101161  1.29368295 -0.10247565 ...  0.          0.
#    1.        ]
#  [-1.73031879 -0.06658201 -0.08002874 ...  0.          0.
#    1.        ]
#  ...
#  [ 1.73031879 -1.30856307 -0.41131362 ...  0.          0.
#    1.        ]
#  [ 1.73101161  0.87968927  0.89863463 ...  0.          1.
#    0.        ]
#  [ 1.73170443 -0.4805757  -0.24879007 ...  0.          1.
#    0.        ]]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (4000, 8) (1000, 8) (4000,) (1000,)
